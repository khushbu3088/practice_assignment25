# %%
import rahul
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import rahul
#
# ModuleNotFoundError: No module named 'rahul'

# %%
pwd
# Out:
# 'D:\\python assignment25'

# %%
import pandas

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
